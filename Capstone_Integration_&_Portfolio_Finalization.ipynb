# %% [markdown]
# <a href="https://colab.research.google.com/github/vtejaswini66/Capstone-Integration-Portfolio-Finalization-Task-5/blob/main/Capstone_Integration_%26_Portfolio_Finalization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("cleaned_dataset.csv")

df.head()
# Out:
#    order_id        date  customer_id product_category   sales  quantity  \
# 0         1  2024-01-01         1051      Electronics  401.51         4
# 1         2  2024-01-02         1092         Clothing  261.27         1
# 2         3  2024-01-03         1014      Electronics  296.91         2
# 3         4  2024-01-04         1071      Electronics  256.41         2
# 4         5  2024-01-05         1060             Home  113.72         4
#
#    marketing_spend  revenue
# 0            82.23  1606.04
# 1            99.97   261.27
# 2            99.68   593.82
# 3            57.77   512.82
# 4            78.05   454.88

# %%
print("Dataset Shape:", df.shape)

print("\nColumns:")
print(df.columns)

print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Dataset Shape: (200, 8)
#
# Columns:
# Index(['order_id', 'date', 'customer_id', 'product_category', 'sales',
#        'quantity', 'marketing_spend', 'revenue'],
#       dtype='object')
#
# Missing Values:
# order_id            0
# date                0
# customer_id         0
# product_category    0
# sales               0
# quantity            0
# marketing_spend     0
# revenue             0
# dtype: int64

# %%
df['date'] = pd.to_datetime(df['date'])

df['month'] = df['date'].dt.month
df['year'] = df['date'].dt.year

# %%
total_revenue = df['revenue'].sum()

total_sales = df['sales'].sum()

total_quantity = df['quantity'].sum()

avg_order_value = df['revenue'].mean()

print("Total Revenue:", total_revenue)
print("Total Sales:", total_sales)
print("Total Quantity:", total_quantity)
print("Average Order Value:", avg_order_value)
# Out:
# Total Revenue: 125980.86
# Total Sales: 53085.119999999995
# Total Quantity: 476
# Average Order Value: 629.9043

# %%
monthly_revenue = df.groupby('month')['revenue'].sum()

plt.figure(figsize=(8,5))

monthly_revenue.plot(kind='line', marker='o')

plt.title("Monthly Revenue Trend")
plt.xlabel("Month")
plt.ylabel("Revenue")

plt.show()

# %%
plt.figure(figsize=(6,4))

sns.histplot(df['sales'], bins=20)

plt.title("Sales Distribution")

plt.show()

# %%
plt.figure(figsize=(6,4))

sns.scatterplot(x='marketing_spend', y='revenue', data=df)

plt.title("Marketing Spend vs Revenue")

plt.show()

# %%
plt.figure(figsize=(6,5))

sns.heatmap(df[['sales','quantity','marketing_spend','revenue']].corr(),
            annot=True)

plt.title("Feature Correlation")

plt.show()

# %%
print("=========== FINAL PROJECT SUMMARY ===========")

print("Dataset Shape:", df.shape)

print("\nKey KPIs")

print("Total Revenue:", total_revenue)
print("Total Sales:", total_sales)
print("Total Quantity Sold:", total_quantity)
print("Average Order Value:", avg_order_value)

print("\nProject Completed Successfully")

print("\nThis capstone project demonstrates:")
print("- Data Cleaning")
print("- Exploratory Data Analysis")
print("- Data Visualization")
print("- Business Insights Generation")
# Out:
# =========== FINAL PROJECT SUMMARY ===========
# Dataset Shape: (200, 10)
#
# Key KPIs
# Total Revenue: 125980.86
# Total Sales: 53085.119999999995
# Total Quantity Sold: 476
# Average Order Value: 629.9043
#
# Project Completed Successfully
#
# This capstone project demonstrates:
# - Data Cleaning
# - Exploratory Data Analysis
# - Data Visualization
# - Business Insights Generation
